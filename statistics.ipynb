# %%
import pandas as pd
import numpy as np
file_name = "winequalityN.csv"
df = pd.read_csv(file_name)
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
df.head(10)
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
# 5  white            8.1              0.28         0.40             6.9
# 6  white            6.2              0.32         0.16             7.0
# 7  white            7.0              0.27         0.36            20.7
# 8  white            6.3              0.30         0.34             1.6
# 9  white            8.1              0.22         0.43             1.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# ...

# %%
df.tail()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# ...

# %%
df.tail(10)
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6487  red            6.6             0.725         0.20             7.8
# 6488  red            6.3             0.550         0.15             1.8
# 6489  red            5.4             0.740         0.09             1.7
# 6490  red            6.3             0.510         0.13             2.3
# 6491  red            6.8             0.620         0.08             1.9
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6487      0.073                 29.0                  79.0  0.99770  3.29
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df["alcohol"].mean()
# Out:
# 10.491800831149511

# %%
df["quality"].mean()
# Out:
# 5.818377712790519

# %%
df["pH"].mean()
# Out:
# 3.218395499383475

# %%
df["citric acid"].mean()
# Out:
# 0.3187218971358124

# %%
df["density"].mean()
# Out:
# 0.9946966338309937

# %% [markdown]
# #  plotting using Histogram

# %%
df.hist(column='alcohol', bins=15)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000211A24C7E80>]],
#       dtype=object)

# %%
df.hist(column='alcohol', bins=10, grid=False, figsize=(10,6), color='green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000211A2C76E50>]],
#       dtype=object)

# %%
df.hist(column='alcohol', bins=10, grid=True, figsize=(10,6), color='green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000211A2CEF2B0>]],
#       dtype=object)

# %%
df.hist(column='alcohol', bins=10, grid=False, figsize=(10,6), color='hotpink')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000211A2D26190>]],
#       dtype=object)

# %%
df.hist(column='alcohol', bins=30, grid=False, figsize=(10,6), color='red')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000211A2DA5A00>]],
#       dtype=object)

# %%
df.hist(column='alcohol', bins=50, grid=False, figsize=(10,6), color='green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000211A2E3ED90>]],
#       dtype=object)

# %% [markdown]
# #  SEABORN

# %%
import seaborn as sns
sns.distplot(df['alcohol'], bins=25, kde=False)

# %%
sns.distplot(df.alcohol, bins=10, kde=True, color="red")

# %%
sns.distplot(df.alcohol, bins=10, kde=True, color="pink")

# %%
sns.distplot(df.alcohol, bins=25, kde=True, color="green")

# %%
sns.distplot(df.alcohol, bins=25, kde=True, color="orange")

# %%
sns.distplot(df.alcohol, bins=50, kde=True, color="hotpink")

# %%
df["alcohol"].value_counts().head()
# Out:
# 9.5     367
# 9.4     332
# 9.2     271
# 10.0    229
# 10.5    227
# Name: alcohol, dtype: int64

# %%
df["alcohol"].value_counts(10).head()
# Out:
# 9.5     0.056488
# 9.4     0.051101
# 9.2     0.041712
# 10.0    0.035247
# 10.5    0.034939
# Name: alcohol, dtype: float64

# %%
df["alcohol"].value_counts().head(10)
# Out:
# 9.5     367
# 9.4     332
# 9.2     271
# 10.0    229
# 10.5    227
# 11.0    217
# 9.0     215
# 9.8     214
# 10.4    194
# 9.3     193
# Name: alcohol, dtype: int64

# %% [markdown]
# # Styling and Axis Labels

# %%
# Let's start with labeling our axis
import matplotlib.pyplot as plt
_ = sns.distplot(df.alcohol)
_ = plt.xlabel('Alcohol Percentage')
_ = plt.ylabel('Count')
_ = plt.title("Alcohol Content")
plt.show()

# %%
#Use sns.set_style() to control styling
sns.set_style("dark")
sns.distplot(df.alcohol, bins=15)

# %%
#Use sns.set_style() to control styling
sns.set_style("whitegrid")
sns.distplot(df.alcohol, bins=25)

# %%
sns.set_style("ticks")
sns.distplot(df.alcohol, bins=50)

# %%
 sns.set_style("darkgrid")
sns.distplot(df.alcohol, bins=50)

# %%
sns.set_style("ticks")
sns.distplot(df.alcohol, bins=50,color = 'orange')

# %%
sns.set_style("darkgrid")
sns.distplot(df.alcohol, bins=50,color = 'hotpink')

# %%
sns.set_style("whitegrid")
sns.distplot(df.alcohol, bins=50,color = 'red')

# %% [markdown]
# # Scatter Plots

# %%
sns.lmplot(x='alcohol', y='fixed acidity', data=df)

# %%
sns.lmplot(x='citric acid', y='fixed acidity', data=df)

# %%
sns.lmplot(x='volatile acidity', y='residual sugar', data=df)

# %%
sns.lmplot(x='alcohol', y='density', data=df, fit_reg=False)

# %%
sns.lmplot(x='alcohol', y='chlorides', data=df, fit_reg=False)

# %%
sns.lmplot(x='free sulfur dioxide', y='chlorides', data=df, fit_reg=False)

# %%
sns.lmplot(x='free sulfur dioxide', y='total sulfur dioxide', data=df, fit_reg=False)

# %%
# Scatterplot arguments
sns.lmplot(x='alcohol', y='chlorides', data=df,
 fit_reg=False, # Remove the regression line
 hue='quality') # Color by quality

# %%
# Scatterplot arguments
sns.lmplot(x='pH', y='chlorides', data=df,
 fit_reg=False, # Remove the regression line
 hue='quality') # Color by quality

# %%
# Scatterplot arguments
sns.lmplot(x='pH', y='sulphates', data=df,
 fit_reg=False, # Remove the regression line
 hue='quality') # Color by quality

# %%
sns.lmplot(x='pH', y='alcohol', data=df,
 fit_reg=False, 
 hue='quality')

# %%
# The quantile function
print(df["alcohol"].quantile(0.1))
print(df["alcohol"].quantile(0.5))
print(df["alcohol"].quantile(0.9))
print(df["alcohol"].quantile(0.99))
# Out:
# 9.1
# 10.3
# 12.3
# 13.4

# %%
# The quantile function
print(df["alcohol"].quantile(0.7))
print(df["alcohol"].quantile(0.99))
print(df["alcohol"].quantile(0.8))
print(df["alcohol"].quantile(0.35))
# Out:
# 11.1
# 13.4
# 11.5
# 9.8

# %%
# The quantile function
print(df["alcohol"].quantile(0.11))
print(df["alcohol"].quantile(0.55))
print(df["alcohol"].quantile(0.98))
print(df["alcohol"].quantile(0.78))
# Out:
# 9.2
# 10.5
# 13.0
# 11.4

# %%
# The quantile function
print(df["residual sugar"].quantile(0.19))
print(df["residual sugar"].quantile(0.95))
print(df["residual sugar"].quantile(0.58))
print(df["residual sugar"].quantile(0.29))
# Out:
# 1.6
# 15.0
# 4.675999999999977
# 1.962999999999988

# %%
# What's the max alcohol value though?
df["alcohol"].max()
# Out:
# 14.9

# %%
df["residual sugar"].max()
# Out:
# 65.8

# %%
df["citric acid"].max()
# Out:
# 1.66

# %%
df["volatile acidity"].max()
# Out:
# 1.58

# %%
df["fixed acidity"].max()
# Out:
# 15.9

# %%
# Quantile ranges
df["alcohol"].quantile(([0.05, 0.95]))
# Out:
# 0.05     9.0
# 0.95    12.7
# Name: alcohol, dtype: float64

# %%
df["citric acid"].quantile(([0.05, 0.95]))
# Out:
# 0.05    0.05
# 0.95    0.56
# Name: citric acid, dtype: float64

# %%
df["quality"].quantile(([0.05, 0.95]))
# Out:
# 0.05    5.0
# 0.95    7.0
# Name: quality, dtype: float64

# %%
df["sulphates"].quantile(([0.05, 0.95]))
# Out:
# 0.05    0.35
# 0.95    0.79
# Name: sulphates, dtype: float64

# %% [markdown]
# # Boxplots & Finding Outliers

# %%
print(df["alcohol"].quantile(([0.25, 0.75])))
sns.boxplot(data=df['alcohol'])
# Out:
# 0.25     9.5
# 0.75    11.3
# Name: alcohol, dtype: float64

# %%
print(df["alcohol"].quantile(([0.25, 0.75])))
sns.boxplot(data=df['chlorides'])
# Out:
# 0.25     9.5
# 0.75    11.3
# Name: alcohol, dtype: float64

# %%
print(df["alcohol"].quantile(([0.25, 0.75])))
sns.boxplot(data=df['fixed acidity'])
# Out:
# 0.25     9.5
# 0.75    11.3
# Name: alcohol, dtype: float64

# %%
print(df["alcohol"].quantile(([0.25, 0.75])))
sns.boxplot(data=df['sulphates'])
# Out:
# 0.25     9.5
# 0.75    11.3
# Name: alcohol, dtype: float64

# %%
print(df["alcohol"].quantile(([0.25, 0.75])))
sns.boxplot(data=df['free sulfur dioxide'])
# Out:
# 0.25     9.5
# 0.75    11.3
# Name: alcohol, dtype: float64

# %%
sns.boxplot(data=df, palette="Set3")

# %%
from matplotlib import pyplot as plt
# Enlarge the plot
plt.figure(figsize=(12,8))
summary = df.drop(['free sulfur dioxide', 'total sulfur dioxide', 'quality',
 'residual sugar', 'fixed acidity', 'alcohol'], axis=1)
sns.boxplot(data=summary, palette="Set3")

# %% [markdown]
# # VIOLIN PLOTS

# %%
sns.violinplot(data=df['alcohol'])

# %%
sns.violinplot(data=df['sulphates'])

# %%
sns.violinplot(data=df['residual sugar'])

# %%
sns.violinplot(data=df['citric acid'])

# %%
sns.violinplot(data=df['fixed acidity'])

# %%
sns.violinplot(data=df['volatile acidity'])

# %%
sns.violinplot(data=df['quality'])

# %%
# Bar Plot
# Enlarge the plot
plt.figure(figsize=(12,8))
sns.countplot(x='quality', data=df, hue='type')

# %%
plt.figure(figsize=(12,10))
sns.countplot(x='alcohol', data=df, hue='type')

# %%
 import urllib.request as r
 r.urlopen('https://bootstrap.pypa.io').close()
# Titanic Example
sns.set(style="whitegrid")
# Load the example Titanic dataset
titanic = sns.load_dataset("titanic")
# Draw a nested barplot to show survival for class and sex
g = sns.catplot(x="class", y="survived", hue="sex", data=titanic, height=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_ylabels("survival probability")

# %%
# Density Plot
sns.kdeplot(df.alcohol, df.density)

# %%
# Joint Distribution Plot
sns.jointplot(x='alcohol', y='density', data=df)

# %%
# Joint Distribution Plot
sns.jointplot(x='alcohol', y='pH', data=df)

# %%
# Joint Distribution Plot
sns.jointplot(x='pH', y='density', data=df)

# %%
# Joint Distribution Plot
sns.jointplot(x='residual sugar', y='density', data=df)

# %% [markdown]
# # Factor Plots and Bee Swarm Plots

# %% [markdown]
# Factor plots allow us to create separate plots by categorical classes

# %%
# Factor Plot
g = sns.catplot(x='free sulfur dioxide',
 y='alcohol',
 data=df,
 # A recent update in Matplotlib broke how the hue argument works in S
 #hue='quality', # Color by stage
 col='quality', # Separate by stage
 kind='point') # Swarmplot
# Rotate x-axis labels
g.set_xticklabels(rotation=-45)

# %% [markdown]
# # Creating Empirical cumulative distribution function (ECDF)

# %%
import numpy as np
x = np.sort(df['alcohol'])
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
plt.margins(0.05)
_ = plt.xlabel('Percent of Alcohol in Wine')
_ = plt.ylabel('ECDF')
plt.grid(True)
plt.show()

# %%
import numpy as np
x = np.sort(df['residual sugar'])
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
plt.margins(0.05)
_ = plt.xlabel('Percent of Alcohol in Wine')
_ = plt.ylabel('ECDF')
plt.grid(True)
plt.show()

# %%
import numpy as np
x = np.sort(df['volatile acidity'])
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
plt.margins(0.05)
_ = plt.xlabel('Percent of Alcohol in Wine')
_ = plt.ylabel('ECDF')
plt.grid(True)
plt.show()

# %%
import numpy as np
x = np.sort(df['sulphates'])
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
plt.margins(0.05)
_ = plt.xlabel('Percent of Alcohol in Wine')
_ = plt.ylabel('ECDF')
plt.grid(True)
plt.show()

# %%
print(df["alcohol"].quantile(([0.2, 0.8])))
# Out:
# 0.2     9.4
# 0.8    11.5
# Name: alcohol, dtype: float64

# %%
print(df["chlorides"].quantile(([0.2, 0.8])))
# Out:
# 0.2    0.036
# 0.8    0.073
# Name: chlorides, dtype: float64

# %%
print(df["fixed acidity"].quantile(([0.2, 0.8])))
# Out:
# 0.2    6.3
# 0.8    7.9
# Name: fixed acidity, dtype: float64
